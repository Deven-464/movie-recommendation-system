# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Extracting features of 2018 movies from Wikipedia

# %%
import pandas as pd
import numpy as np
import requests
import time
from io import StringIO

# %%
url = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)

tables = pd.read_html(StringIO(response.text))

df1 = tables[2]
df2 = tables[3]
df3 = tables[4]
df4 = tables[5]

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# %%
df1 = df[['Title']]

print(df1.head())
# Out:
#                      Title
# 0  Insidious: The Last Key
# 1         The Strange Ones
# 2             The Commuter
# 3               Proud Mary
# 4         Acts of Violence

# %%
API_KEY = "da8a88c9410d08718361982f107d161f"

tmdb_headers = {
    "User-Agent": "Mozilla/5.0"
}

# %%
import requests
import numpy as np
import time

API_KEY = "da8a88c9410d08718361982f107d161f"

session = requests.Session()

session.headers.update({
    "User-Agent": "Mozilla/5.0",
    "Connection": "keep-alive"
})

def get_movie_genres(title):

    for attempt in range(3):

        try:

            # SEARCH MOVIE
            search_url = "https://api.themoviedb.org/3/search/movie"

            search_response = session.get(
                search_url,
                params={
                    "api_key": API_KEY,
                    "query": title
                },
                timeout=30
            )

            search_data = search_response.json()

            if len(search_data["results"]) == 0:
                return np.nan

            movie_id = search_data["results"][0]["id"]

            # MOVIE DETAILS
            details_url = f"https://api.themoviedb.org/3/movie/{movie_id}"

            details_response = session.get(
                details_url,
                params={
                    "api_key": API_KEY
                },
                timeout=30
            )

            details_data = details_response.json()

            genres = [g["name"] for g in details_data["genres"]]

            time.sleep(0)

            return " ".join(genres)

        except Exception as e:

            print(f"Retry {attempt+1} failed for {title}")

            time.sleep(5)

    return np.nan

# %%
df1 = df1.copy()

genres_list = []

for title in df1["Title"]:

    genres = get_movie_genres(title)

    print(title, "->", genres)

    genres_list.append(genres)

df["genres"] = genres_list

print(df)
# Out:
# Insidious: The Last Key -> Horror Thriller
# The Strange Ones -> Drama Mystery
# The Commuter -> Action Thriller Mystery
# Proud Mary -> Thriller Action Crime
# Acts of Violence -> Action Crime Thriller
# Freak Show -> Comedy Drama
# Humor Me -> Comedy
# 12 Strong -> War Drama Action History
# Den of Thieves -> Crime Thriller Action
# Forever My Girl -> Romance Drama
# Thane of East County -> Drama Thriller
# Maze Runner: The Death Cure -> Science Fiction Action Adventure Thriller
# Please Stand By -> Comedy Drama
# Winchester -> Horror Thriller
# A Fantastic Woman -> Drama
# Armed -> Action Comedy Crime
# The Cloverfield Paradox -> Horror Mystery Science Fiction
# Bad Apples -> Comedy Thriller
# Peter Rabbit -> Animation Adventure Family
# Pad Man -> Comedy Drama
# Fifty Shades Freed -> Drama Romance
# The 15:17 to Paris -> Drama Thriller
# Permission -> Comedy Romance Drama
# Golden Exits -> Drama
# Black Panther -> Action Adventure Science Fiction
# Looking Glass -> Adventure Family Fantasy
# Nostalgia -> Drama Romance
# Samson -> Action Drama Adventure
# Game Night -> Mystery Comedy Crime
# Annihilation -> Science Fiction Horror
# Every Day -> Romance Fantasy
# The Cured -> Horror Drama Science Fiction
# Red Sparrow -> Thriller Mystery
# Death Wish -> Action Crime Thriller Drama
# The Vanishing of Sidney Hall -> Drama Mystery Romance
# Pickings -> Thriller Action Crime Drama Mystery
# A Wrinkle in Time -> Adventure Science Fiction Family Fantasy
# Gringo -> Comedy Action Crime
# Thoroughbreds -> Drama Thriller
# The Strangers: Prey at Night -> Horror Thriller
# The Hurricane Heist -> Action Adventure Crime Thriller
# Tomb Raider -> Action Adventure Fantasy
# Love, Simon -> Comedy Drama Romance
# I Can Only Imagine -> Music Drama
# Entebbe -> Thriller Drama Crime
# Furlough -> Drama
# Josie -> Thriller Drama
# Flower -> Crime History Drama
# Pacific Rim Uprising -> Action Fantasy Science Fiction Adventure
# Isle of Dogs -> Adventure Comedy Animation
# Sherlock Gnomes -> Animation Family Fantasy Comedy Adventure Mystery
# Unsane -> Horror Thriller
# Paul, Apostle of Christ -> Drama
# Final Portrait -> History Drama
# Midnight Sun -> Romance Drama
# Ready Player One -> Adventure Action Science Fiction
# Acrimony -> Drama Thriller
# God's Not Dead: A Light in Darkness -> Drama
# Gemini -> Science Fiction Action Adventure Thriller Drama
# The Last Movie Star -> Drama
# A Quiet Place -> Horror Drama Science Fiction
# Blockers -> Comedy
# You Were Never Really Here -> Crime Drama Thriller
# Chappaquiddick -> History Drama Thriller
# The Miracle Season -> Drama
# Paterno -> Drama TV Movie
# Beirut -> Action Thriller Drama
# Rampage -> Action Adventure Science Fiction
# Truth or Dare -> Thriller Horror
# The Rider -> Drama Western
# Sgt. Stubby: An American Hero -> Animation Adventure Family History War
# Sign Gene -> Science Fiction Adventure
# I Feel Pretty -> Comedy Romance
# Super Troopers 2 -> Comedy Crime Mystery
# Traffik -> Thriller Action
# The House of Tomorrow -> Drama Comedy
# Avengers: Infinity War -> Adventure Action Science Fiction
# Disobedience -> Drama Romance
# Backstabbing for Beginners -> Thriller Drama History
# Kings -> Adventure Animation Family Fantasy
# Overboard -> Romance Comedy
# Tully -> Comedy Drama
# Bad Samaritan -> Thriller Crime Horror Drama
# The Cleanse -> Drama Comedy Fantasy Horror
# RBG -> Documentary
# Life of the Party -> Comedy
# Breaking In -> Action Crime Thriller
# The Seagull -> Drama TV Movie
# Terminal -> Comedy Drama
# Deadpool 2 -> Action Comedy Adventure
# Show Dogs -> Adventure Crime Family Comedy
# Book Club -> Romance
# First Reformed -> Drama
# Fahrenheit 451 -> Drama Science Fiction
# Solo: A Star Wars Story -> Science Fiction Adventure Action
# How to Talk to Girls at Parties -> Comedy Music Romance Science Fiction
# In Darkness -> Horror Adventure
# Future World -> Science Fiction
# The Tale -> Fantasy Drama Adventure
# Action Point -> Comedy Drama
# Adrift -> Thriller Romance Adventure
# Upgrade -> Action Thriller Science Fiction
# American Animals -> Drama Crime Documentary
# Social Animals -> Comedy Romance
# Ocean's 8 -> Crime Comedy Action
# Hereditary -> Horror Mystery Thriller
# Hotel Artemis -> Science Fiction Crime Action Thriller Drama
# Superfly -> Action Crime
# Incredibles 2 -> Action Adventure Animation Family
# Tag -> Comedy Action
# Gotti -> Crime Drama History Thriller
# Jurassic World: Fallen Kingdom -> Adventure Science Fiction Thriller
# Boundaries -> Comedy Drama
# Damsel -> Fantasy Action Adventure
# The Domestics -> Horror Thriller
# Sicario: Day of the Soldado -> Action Crime Thriller
# Leave No Trace -> Drama
# Love All You Have Left -> Drama
# Uncle Drew -> Comedy
# Woman Walks Ahead -> Drama History Western
# Who's Watching Oliver -> Horror TV Movie
# The First Purge -> Action Horror Thriller
# Ant-Man and the Wasp -> Action Adventure Science Fiction
# Sorry to Bother You -> Fantasy Science Fiction Comedy
# Whitney -> Music Documentary
# Hotel Transylvania 3: Summer Vacation -> Animation Comedy Family Fantasy
# Skyscraper -> Action Thriller Adventure
# Eighth Grade -> Comedy Drama
# Don't Worry, He Won't Get Far on Foot -> Comedy Drama
# Shock and Awe -> History Drama Thriller
# Mamma Mia! Here We Go Again -> Comedy Romance
# The Equalizer 2 -> Action Thriller Crime
# Blindspotting -> Comedy Crime Drama
# Unfriended: Dark Web -> Horror
# Mission: Impossible – Fallout -> Action Adventure
# Teen Titans Go! To the Movies -> Animation Action Comedy Science Fiction
# Hot Summer Nights -> Drama Crime
# Puzzle -> Horror Thriller
# Extinction -> Action Drama Science Fiction Thriller
# Christopher Robin -> Adventure Comedy Family Fantasy
# The Darkest Minds -> Action Adventure Drama
# The Spy Who Dumped Me -> Comedy Action Adventure
# The Miseducation of Cameron Post -> Drama
# Never Goin' Back -> Comedy
# Dog Days -> Comedy Family Romance
# The Meg -> Action Science Fiction Horror
# BlacKkKlansman -> Crime Comedy Drama History
# Slender Man -> Horror Mystery Thriller
# A Prayer Before Dawn -> Drama Action Crime
# Elizabeth Harvest -> Science Fiction Thriller Horror Mystery
# Crazy Rich Asians -> Comedy Romance
# Alpha -> Horror Drama Science Fiction
# Mile 22 -> Action Thriller
# The Wife -> Drama
# Billionaire Boys Club -> Drama
# Juliet, Naked -> Comedy Drama Romance
# Down a Dark Hall -> Horror Mystery Thriller Fantasy Drama
# To All the Boys I've Loved Before -> Comedy Romance
# The Happytime Murders -> Action Crime Comedy
# Searching -> Drama TV Movie
# Papillon -> Adventure Crime Drama
# A.X.L. -> Science Fiction Action Adventure Family
# Operation Finale -> Drama History Thriller
# Kin -> Science Fiction Action Adventure Thriller
# Destination Wedding -> Romance Comedy Drama
# Reprisal -> Action Adventure Thriller
# The Nun -> Horror
# Peppermint -> Action Thriller
# The Predator -> Science Fiction Action Thriller
# A Simple Favor -> Thriller Comedy Mystery
# White Boy Rick -> Crime Drama
# Unbroken: Path to Redemption -> Drama
# The Children Act -> Drama
# Lizzie -> Crime Drama Thriller
# Hell House LLC II: The Abaddon Hotel -> Horror Mystery
# The House with a Clock in Its Walls -> Comedy Family Fantasy Horror Mystery
# Life Itself -> Drama Romance
# The Sisters Brothers -> Western Drama Comedy
# Assassination Nation -> Thriller Horror Comedy
# Little Italy -> Comedy Romance
# Colette -> Drama History
# Fahrenheit 11/9 -> Documentary
# Love, Gilda -> Documentary
# Smallfoot -> Family Comedy Adventure Animation Fantasy
# Night School -> Comedy
# The Old Man & the Gun -> Comedy Crime Drama
# Hell Fest -> Horror Thriller
# Venom -> Science Fiction Action
# A Star Is Born -> Music Drama Romance
# The Great Buster: A Celebration -> Documentary Comedy
# First Man -> History Drama
# Bad Times at the El Royale -> Thriller Mystery Crime
# Goosebumps 2: Haunted Halloween -> Comedy Fantasy Horror Family
# Beautiful Boy -> Drama
# The Oath -> Comedy Thriller
# Gosnell: The Trial of America's Biggest Serial Killer -> Drama Crime Documentary
# After Everything -> Romance Drama
# Halloween -> Horror Thriller
# The Hate U Give -> Crime Drama
# Can You Ever Forgive Me? -> Drama Crime Comedy
# Mid90s -> Drama Comedy
# Wildlife -> Drama
# What They Had -> Drama
# My Dinner with Hervé -> Drama TV Movie
# Hunter Killer -> Action Adventure Thriller
# Johnny English Strikes Again -> Action Adventure Comedy
# Suspiria -> Horror
# Indivisible -> Drama War
# Bullitt County -> Action Drama Thriller
# Bohemian Rhapsody -> Music Drama
# The Nutcracker and the Four Realms -> Family Fantasy Adventure
# Nobody's Fool -> Drama Comedy
# Boy Erased -> Drama
# The Other Side of the Wind -> Drama
# A Private War -> Drama War
# Prospect -> Science Fiction
# Bodied -> Drama Comedy Music
# The Front Runner -> Drama History
# The Grinch -> Animation Comedy Family Fantasy
# The Girl in the Spider's Web -> Action Crime Thriller
# Overlord -> Horror War Science Fiction
# The Ballad of Buster Scruggs -> Western Comedy Drama
# Lazer Team 2 -> Science Fiction Action Adventure Comedy
# Fantastic Beasts: The Crimes of Grindelwald -> Fantasy Adventure
# Widows -> Drama Crime Thriller
# Green Book -> Drama Comedy History
# Instant Family -> Comedy Drama
# Ralph Breaks the Internet -> Action Adventure Animation Comedy Family Science Fiction
# Creed II -> Drama Action
# Robin Hood -> Thriller Action Drama
# Roma -> Drama
# The Christmas Chronicles -> Comedy Adventure Family Fantasy
# The Favourite -> History Comedy Drama
# Mowgli: Legend of the Jungle -> Adventure Drama
# The Possession of Hannah Grace -> Horror Drama
# The Cabin -> Horror Mystery Comedy
# Mary Queen of Scots -> Drama History
# Ben Is Back -> Drama
# Spider-Man: Into the Spider-Verse -> Animation Action Adventure Science Fiction
# Mortal Engines -> Adventure Science Fiction
# The Mule -> Crime Drama
# If Beale Street Could Talk -> Romance Drama
# Mary Poppins Returns -> Fantasy Family Comedy
# Aquaman -> Action Adventure Fantasy
# Bumblebee -> Action Adventure Science Fiction
# Welcome to Marwen -> Drama Comedy
# Second Act -> Romance Comedy
# Holmes & Watson -> Comedy Mystery Crime
# Vice -> Drama Comedy
# On the Basis of Sex -> Drama History
# Destroyer -> Thriller Crime Drama Action
#              Opening  Opening.1                    Title  \
# 0      J A N U A R Y          5  Insidious: The Last Key
# 1      J A N U A R Y          5         The Strange Ones
# 2      J A N U A R Y         12             The Commuter
# 3      J A N U A R Y         12               Proud Mary
# 4      J A N U A R Y         12         Acts of Violence
# ..               ...        ...                      ...
# 246  D E C E M B E R         21               Second Act
# 247  D E C E M B E R         25          Holmes & Watson
# 248  D E C E M B E R         25                     Vice
# 249  D E C E M B E R         25      On the Basis of Sex
# 250  D E C E M B E R         25                Destroyer
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2        Lionsgate / StudioCanal / The Picture Company
# 3                                          Screen Gems
# 4                                   Lionsgate Premiere
# ..                                                 ...
# 246                                  STX Entertainment
# 247  Columbia Pictures / Gary Sanchez Productions /...
# 248          Annapurna Pictures / Plan B Entertainment
# 249                                     Focus Features
# 250                                 Annapurna Pictures
#
#                                          Cast and crew   Ref.  \
# 0    Adam Robitel (director); Leigh Whannell (scree...    [2]
# 1    Christopher Radcliff (director/screenplay); La...    [3]
# 2    Jaume Collet-Serra (director); Byron Willinger...    [4]
# 3    Babak Najafi (director); John S. Newman, Chris...    [5]
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...    [6]
# ..                                                 ...    ...
# 246  Peter Segal (director); Justin Zackham, Elaine...  [238]
# 247  Etan Cohen (director/screenplay); Will Ferrell...  [142]
# 248  Adam McKay (director/screenplay); Christian Ba...  [117]
# 249  Mimi Leder (director); Daniel Stiepleman (scre...  [207]
# 250  Karyn Kusama (director); Phil Hay, Matt Manfre...  [239]
#
#                           genres
# 0                Horror Thriller
# 1                  Drama Mystery
# 2        Action Thriller Mystery
# 3          Thriller Action Crime
# 4          Action Crime Thriller
# ..                           ...
# 246               Romance Comedy
# 247         Comedy Mystery Crime
# 248                 Drama Comedy
# 249                Drama History
# 250  Thriller Crime Drama Action
#
# [251 rows x 7 columns]

# %%
# %pip install lxml

# %%
# %pip install --upgrade requests urllib3 certifi

# %%
df
# Out:
#              Opening  Opening.1                    Title  \
# 0      J A N U A R Y          5  Insidious: The Last Key
# 1      J A N U A R Y          5         The Strange Ones
# 2      J A N U A R Y         12             The Commuter
# 3      J A N U A R Y         12               Proud Mary
# 4      J A N U A R Y         12         Acts of Violence
# ..               ...        ...                      ...
# 246  D E C E M B E R         21               Second Act
# 247  D E C E M B E R         25          Holmes & Watson
# 248  D E C E M B E R         25                     Vice
# 249  D E C E M B E R         25      On the Basis of Sex
# 250  D E C E M B E R         25                Destroyer
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2        Lionsgate / StudioCanal / The Picture Company
# 3                                          Screen Gems
# 4                                   Lionsgate Premiere
# ..                                                 ...
# 246                                  STX Entertainment
# 247  Columbia Pictures / Gary Sanchez Productions /...
# 248          Annapurna Pictures / Plan B Entertainment
# 249                                     Focus Features
# 250                                 Annapurna Pictures
#
#                                          Cast and crew   Ref.  \
# 0    Adam Robitel (director); Leigh Whannell (scree...    [2]
# 1    Christopher Radcliff (director/screenplay); La...    [3]
# 2    Jaume Collet-Serra (director); Byron Willinger...    [4]
# 3    Babak Najafi (director); John S. Newman, Chris...    [5]
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...    [6]
# ..                                                 ...    ...
# 246  Peter Segal (director); Justin Zackham, Elaine...  [238]
# 247  Etan Cohen (director/screenplay); Will Ferrell...  [142]
# 248  Adam McKay (director/screenplay); Christian Ba...  [117]
# 249  Mimi Leder (director); Daniel Stiepleman (scre...  [207]
# 250  Karyn Kusama (director); Phil Hay, Matt Manfre...  [239]
#
#                           genres
# 0                Horror Thriller
# 1                  Drama Mystery
# 2        Action Thriller Mystery
# 3          Thriller Action Crime
# 4          Action Crime Thriller
# ..                           ...
# 246               Romance Comedy
# 247         Comedy Mystery Crime
# 248                 Drama Comedy
# 249                Drama History
# 250  Thriller Crime Drama Action
#
# [251 rows x 7 columns]

# %%
df_2018 = df[['Title','Cast and crew','genres']]

# %%
df_2018["Cast and crew"][1]
# Out:
# 'Christopher Radcliff (director/screenplay); Lauren Wolkstein (director); Alex Pettyfer, James Freedson-Jackson, Emily Althaus, Gene Jones, Owen Campbell, Tobias Campbell'

# %%
df_2018.head(5)
# Out:
#                      Title                                      Cast and crew  \
# 0  Insidious: The Last Key  Adam Robitel (director); Leigh Whannell (scree...
# 1         The Strange Ones  Christopher Radcliff (director/screenplay); La...
# 2             The Commuter  Jaume Collet-Serra (director); Byron Willinger...
# 3               Proud Mary  Babak Najafi (director); John S. Newman, Chris...
# 4         Acts of Violence  Brett Donowho (director); Nicolas Aaron Mezzan...
#
#                     genres
# 0          Horror Thriller
# 1            Drama Mystery
# 2  Action Thriller Mystery
# 3    Thriller Action Crime
# 4    Action Crime Thriller

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay);")[0]

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7404\930721595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7404\2274966287.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1].split(", "))) <2 :
        return np.nan
    else:
         return ((x.split("screeplay); ")[-1].split(", ")[1]))

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7404\3672495884.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.nan
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018
# Out:
#                        Title  \
# 0    Insidious: The Last Key
# 1           The Strange Ones
# 2               The Commuter
# 3                 Proud Mary
# 4           Acts of Violence
# ..                       ...
# 246               Second Act
# 247          Holmes & Watson
# 248                     Vice
# 249      On the Basis of Sex
# 250                Destroyer
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Christopher Radcliff (director/screenplay); La...
# 2    Jaume Collet-Serra (director); Byron Willinger...
# 3    Babak Najafi (director); John S. Newman, Chris...
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...
# ..                                                 ...
# 246  Peter Segal (director); Justin Zackham, Elaine...
# 247  Etan Cohen (director/screenplay); Will Ferrell...
# 248  Adam McKay (director/screenplay); Christian Ba...
# 249  Mimi Leder (director); Daniel Stiepleman (scre...
# 250  Karyn Kusama (director); Phil Hay, Matt Manfre...
#
#                           genres  \
# 0                Horror Thriller
# 1                  Drama Mystery
# 2        Action Thriller Mystery
# 3          Thriller Action Crime
# 4          Action Crime Thriller
# ..                           ...
# 246               Romance Comedy
# 247         Comedy Mystery Crime
# 248                 Drama Comedy
# 249                Drama History
# 250  Thriller Crime Drama Action
#
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 246                                        Peter Segal
# 247                                         Etan Cohen
# 248                                         Adam McKay
# 249                                         Mimi Leder
# 250                                       Karyn Kusama
#
#                                    actor_1_name  \
# 0                                     Lin Shaye
# 1    Lauren Wolkstein (director); Alex Pettyfer
# 2                                   Liam Neeson
# 3                              Taraji P. Henson
# 4                                  Bruce Willis
# ..                                          ...
# 246                              Jennifer Lopez
# 247                                Will Ferrell
# 248                              Christian Bale
# 249                              Felicity Jones
# 250                               Nicole Kidman
#
#                                           actor_2_name     actor_3_name
# 0                                        Angus Sampson   Leigh Whannell
# 1                               James Freedson-Jackson    Emily Althaus
# 2                                      Philip de Blasi   Patrick Wilson
# 3                                     Christian Swegal      Billy Brown
# 4                                          Cole Hauser    Shawn Ashmore
# ..                                                 ...              ...
# 246  Elaine Goldsmith-Thomas (screenplay); Jennifer...  Vanessa Hudgens
# 247                                     John C. Reilly     Rebecca Hall
# 248                                          Amy Adams     Steve Carell
# 249                                       Armie Hammer   Justin Theroux
# 250          Matt Manfredi (screenplay); Nicole Kidman     Toby Kebbell
#
# [251 rows x 7 columns]

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18
# Out:
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 246                                        Peter Segal
# 247                                         Etan Cohen
# 248                                         Adam McKay
# 249                                         Mimi Leder
# 250                                       Karyn Kusama
#
#                                    actor_1_name  \
# 0                                     Lin Shaye
# 1    Lauren Wolkstein (director); Alex Pettyfer
# 2                                   Liam Neeson
# 3                              Taraji P. Henson
# 4                                  Bruce Willis
# ..                                          ...
# 246                              Jennifer Lopez
# 247                                Will Ferrell
# 248                              Christian Bale
# 249                              Felicity Jones
# 250                               Nicole Kidman
#
#                                           actor_2_name     actor_3_name  \
# 0                                        Angus Sampson   Leigh Whannell
# 1                               James Freedson-Jackson    Emily Althaus
# 2                                      Philip de Blasi   Patrick Wilson
# 3                                     Christian Swegal      Billy Brown
# 4                                          Cole Hauser    Shawn Ashmore
# ..                                                 ...              ...
# 246  Elaine Goldsmith-Thomas (screenplay); Jennifer...  Vanessa Hudgens
# 247                                     John C. Reilly     Rebecca Hall
# 248                                          Amy Adams     Steve Carell
# 249                                       Armie Hammer   Justin Theroux
# 250          Matt Manfredi (screenplay); Nicole Kidman     Toby Kebbell
#
#                           genres              movie_title
# 0                Horror Thriller  Insidious: The Last Key
# 1                  Drama Mystery         The Strange Ones
# 2        Action Thriller Mystery             The Commuter
# 3          Thriller Action Crime               Proud Mary
# 4          Action Crime Thriller         Acts of Violence
# ..                           ...                      ...
# 246               Romance Comedy               Second Act
# 247         Comedy Mystery Crime          Holmes & Watson
# 248                 Drama Comedy                     Vice
# 249                Drama History      On the Basis of Sex
# 250  Thriller Crime Drama Action                Destroyer
#
# [251 rows x 6 columns]

# %%
new_df18.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      5
# actor_3_name     17
# genres            0
# movie_title       0
# dtype: int64

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']

# %%
new_df18
# Out:
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 246                                        Peter Segal
# 247                                         Etan Cohen
# 248                                         Adam McKay
# 249                                         Mimi Leder
# 250                                       Karyn Kusama
#
#                                    actor_1_name  \
# 0                                     Lin Shaye
# 1    Lauren Wolkstein (director); Alex Pettyfer
# 2                                   Liam Neeson
# 3                              Taraji P. Henson
# 4                                  Bruce Willis
# ..                                          ...
# 246                              Jennifer Lopez
# 247                                Will Ferrell
# 248                              Christian Bale
# 249                              Felicity Jones
# 250                               Nicole Kidman
#
#                                           actor_2_name     actor_3_name  \
# 0                                        Angus Sampson   Leigh Whannell
# 1                               James Freedson-Jackson    Emily Althaus
# 2                                      Philip de Blasi   Patrick Wilson
# 3                                     Christian Swegal      Billy Brown
# 4                                          Cole Hauser    Shawn Ashmore
# ..                                                 ...              ...
# 246  Elaine Goldsmith-Thomas (screenplay); Jennifer...  Vanessa Hudgens
# 247                                     John C. Reilly     Rebecca Hall
# 248                                          Amy Adams     Steve Carell
# 249                                       Armie Hammer   Justin Theroux
# 250          Matt Manfredi (screenplay); Nicole Kidman     Toby Kebbell
#
#                           genres              movie_title  \
# 0                Horror Thriller  insidious: the last key
# 1                  Drama Mystery         the strange ones
# 2        Action Thriller Mystery             the commuter
# 3          Thriller Action Crime               proud mary
# 4          Action Crime Thriller         acts of violence
# ..                           ...                      ...
# 246               Romance Comedy               second act
# 247         Comedy Mystery Crime          holmes & watson
# 248                 Drama Comedy                     vice
# 249                Drama History      on the basis of sex
# 250  Thriller Crime Drama Action                destroyer
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Lauren Wolkstein (director); Alex Pettyfer Jam...
# 2    Liam Neeson Philip de Blasi Patrick Wilson Jau...
# 3    Taraji P. Henson Christian Swegal Billy Brown ...
# 4    Bruce Willis Cole Hauser Shawn Ashmore Brett D...
# ..                                                 ...
# 246  Jennifer Lopez Elaine Goldsmith-Thomas (screen...
# 247  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 248  Christian Bale Amy Adams Steve Carell Adam McK...
# 249  Felicity Jones Armie Hammer Justin Theroux Mim...
# 250  Nicole Kidman Matt Manfredi (screenplay); Nico...
#
# [251 rows x 7 columns]

# %% [markdown]
# ## Extracting features of 2019 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
headers = {"User-Agent": "Mozilla/5.0"}
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[33], line 3
#       1 link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
#       2 headers = {"User-Agent": "Mozilla/5.0"}
# ----> 3 df1 = pd.read_html(link, header=0)[2]
#       4 df2 = pd.read_html(link, header=0)[3]
#       5 df3 = pd.read_html(link, header=0)[4]
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)
#    1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
#    1234         "will be removed in a future version. To read from a "
#    (...)
#    1237         stacklevel=find_stack_level(),
#    1238     )
# -> 1240 return _parse(
#    1241     flavor=flavor,
#    1242     io=io,
#    1243     match=match,
#    1244     header=header,
#    1245     index_col=index_col,
#    1246     skiprows=skiprows,
#    1247     parse_dates=parse_dates,
#    1248     thousands=thousands,
#    1249     attrs=attrs,
#    1250     encoding=encoding,
#    1251     decimal=decimal,
#    1252     converters=converters,
#    1253     na_values=na_values,
#    1254     keep_default_na=keep_default_na,
#    1255     displayed_only=displayed_only,
#    1256     extract_links=extract_links,
#    1257     dtype_backend=dtype_backend,
#    1258     storage_options=storage_options,
#    1259 )
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\html.py:983, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, storage_options, **kwargs)
#     972 p = parser(
#     973     io,
#     974     compiled_match,
#    (...)
#     979     storage_options,
#     980 )
#     982 try:
# --> 983     tables = p.parse_tables()
#     984 except ValueError as caught:
#     985     # if `io` is an io-like object, check if it's seekable
#     986     # and try to rewind it before trying the next parser
#     987     if hasattr(io, "seekable") and io.seekable():
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\html.py:249, in _HtmlFrameParser.parse_tables(self)
#     241 def parse_tables(self):
#     242     """
#     243     Parse and return all tables from the DOM.
#     244
#    (...)
#     247     list of parsed (header, body, footer) tuples from tables.
#     248     """
# --> 249     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     250     return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\html.py:806, in _LxmlFrameParser._build_doc(self)
#     804             pass
#     805     else:
# --> 806         raise e
#     807 else:
#     808     if not hasattr(r, "text_content"):
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\html.py:785, in _LxmlFrameParser._build_doc(self)
#     783 try:
#     784     if is_url(self.io):
# --> 785         with get_handle(
#     786             self.io, "r", storage_options=self.storage_options
#     787         ) as f:
#     788             r = parse(f.handle, parser=parser)
#     789     else:
#     790         # try to parse the input in the simplest way
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\common.py:728, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     725     codecs.lookup_error(errors)
#     727 # open URLs
# --> 728 ioargs = _get_filepath_or_buffer(
#     729     path_or_buf,
#     730     encoding=encoding,
#     731     compression=compression,
#     732     mode=mode,
#     733     storage_options=storage_options,
#     734 )
#     736 handle = ioargs.filepath_or_buffer
#     737 handles: list[BaseBuffer]
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\common.py:384, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     382 # assuming storage_options is to be interpreted as headers
#     383 req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 384 with urlopen(req_info) as req:
#     385     content_encoding = req.headers.get("Content-Encoding", None)
#     386     if content_encoding == "gzip":
#     387         # Override compression based on Content-Encoding header
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\common.py:289, in urlopen(*args, **kwargs)
#     283 """
#     284 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     285 the stdlib.
#     286 """
#     287 import urllib.request
# --> 289 return urllib.request.urlopen(*args, **kwargs)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py:189, in urlopen(url, data, timeout, context)
#     187 else:
#     188     opener = _opener
# --> 189 return opener.open(url, data, timeout)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py:495, in OpenerDirector.open(self, fullurl, data, timeout)
#     493 for processor in self.process_response.get(protocol, []):
#     494     meth = getattr(processor, meth_name)
# --> 495     response = meth(req, response)
#     497 return response
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py:604, in HTTPErrorProcessor.http_response(self, request, response)
#     601 # According to RFC 2616, "2xx" code indicates that the client's
#     602 # request was successfully received, understood, and accepted.
#     603 if not (200 <= code < 300):
# --> 604     response = self.parent.error(
#     605         'http', request, response, code, msg, hdrs)
#     607 return response
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py:533, in OpenerDirector.error(self, proto, *args)
#     531 if http_err:
#     532     args = (dict, 'default', 'http_error_default') + orig_args
# --> 533     return self._call_chain(*args)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py:466, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     464 for handler in handlers:
#     465     func = getattr(handler, meth_name)
# --> 466     result = func(*args)
#     467     if result is not None:
#     468         return result
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py:613, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     612 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 613     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 403: Forbidden

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(link, headers=headers)

tables = pd.read_html(StringIO(response.text))

df1 = tables[2]
df2 = tables[3]
df3 = tables[4]
df4 = tables[5]

# %%
df = pd.concat([df1,df2, df3, df4], ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1              Title  \
# 0      J A N U A R Y          4        Escape Room
# 1      J A N U A R Y          4         Rust Creek
# 2      J A N U A R Y          4   American Hangman
# 3      J A N U A R Y         11   A Dog's Way Home
# 4      J A N U A R Y         11         The Upside
# ..               ...        ...                ...
# 247  D E C E M B E R         25  Spies in Disguise
# 248  D E C E M B E R         25       Little Women
# 249  D E C E M B E R         25               1917
# 250  D E C E M B E R         25         Just Mercy
# 251  D E C E M B E R         27           Clemency
#
#                                     Production company  \
# 0                    Columbia Pictures / Original Film
# 1                       IFC Films / Lunacy Productions
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ..                                                 ...
# 247  20th Century Fox Animation / Blue Sky Studios ...
# 248            Columbia Pictures / Regency Enterprises
# 249           Universal Pictures / DreamWorks Pictures
# 250                Warner Bros. Pictures / Participant
# 251                                               Neon
#
#                                          Cast and crew   Ref.
# 0    Adam Robitel (director); Bragi F. Schut, Maria...    [2]
# 1    Jen McGowan (director); Julie Lipson (screenpl...    [3]
# 2    Wilson Coneybeare (director/screenplay); Donal...    [4]
# 3    Charles Martin Smith (director); W. Bruce Came...    [5]
# 4    Neil Burger (director); Jon Hartmere (screenpl...    [6]
# ..                                                 ...    ...
# 247  Nick Bruno, Troy Quane (directors); Brad Copel...  [133]
# 248  Greta Gerwig (director/screenplay); Saoirse Ro...  [228]
# 249  Sam Mendes (director/screenplay); Krysty Wilso...  [229]
# 250  Destin Daniel Cretton (director/screenplay), A...  [230]
# 251  Chinonye Chukwu (director/screenplay); Alfre W...  [231]
#
# [252 rows x 6 columns]

# %%
df['genres'] = df['Title'].map(lambda x: get_movie_genres(str(x)))
# Out:
# Retry 1 failed for Escape Room

# %%
df_2019 = df[['Title','Cast and crew','genres']]

# %%
df_2019
# Out:
#                  Title                                      Cast and crew  \
# 0          Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1           Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2     American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3     A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4           The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                 ...                                                ...
# 247  Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 248       Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 249               1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 250         Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 251           Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#                                        genres
# 0                     Horror Thriller Mystery
# 1                 Thriller Drama Action Crime
# 2                                    Thriller
# 3                      Drama Adventure Family
# 4                                Comedy Drama
# ..                                        ...
# 247  Animation Action Adventure Comedy Family
# 248                             Drama Romance
# 249                         War History Drama
# 250                       Drama Crime History
# 251                                     Drama
#
# [252 rows x 3 columns]

# %%
df_2019.loc[0,"Cast and crew"]
# Out:
# 'Adam Robitel (director); Bragi F. Schut, Maria Melnik (screenplay); Taylor Russell, Logan Miller, Deborah Ann Woll, Tyler Labine, Jay Ellis, Nik Dodani, Yorick van Wageningen'

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else: 
        return x.split(" (director/screenplay)")[0]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7404\203239715.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("((screenplay);)")[-1].split(", ")[0]))

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7404\1562076556.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("(screenplay); ")[-1].split(", ")))<2:
        return np.nan
    else: 
        return ((x.split("(screenplay); ")[-1]).split(", ")[1])

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7404\3736213850.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.nan
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']

# %%
new_df19
# Out:
#               director_name  \
# 0              Adam Robitel
# 1               Jen McGowan
# 2         Wilson Coneybeare
# 3      Charles Martin Smith
# 4               Neil Burger
# ..                      ...
# 247  Nick Bruno, Troy Quane
# 248            Greta Gerwig
# 249              Sam Mendes
# 250   Destin Daniel Cretton
# 251         Chinonye Chukwu
#
#                                           actor_1_name          actor_2_name  \
# 0              Adam Robitel (director); Bragi F. Schut          Logan Miller
# 1    Jen McGowan (director); Julie Lipson (screenpl...           Jay Paulson
# 2    Wilson Coneybeare (director/screenplay); Donal...    Vincent Kartheiser
# 3    Charles Martin Smith (director); W. Bruce Came...    Edward James Olmos
# 4    Neil Burger (director); Jon Hartmere (screenpl...            Kevin Hart
# ..                                                 ...                   ...
# 247                                         Nick Bruno           Tom Holland
# 248  Greta Gerwig (director/screenplay); Saoirse Ronan           Emma Watson
# 249  Sam Mendes (director/screenplay); Krysty Wilso...  Dean-Charles Chapman
# 250        Destin Daniel Cretton (director/screenplay)            Jamie Foxx
# 251  Chinonye Chukwu (director/screenplay); Alfre W...        Wendell Pierce
#
#          actor_3_name                                    genres  \
# 0    Deborah Ann Woll                   Horror Thriller Mystery
# 1        Sean O'Bryan               Thriller Drama Action Crime
# 2       Oliver Dennis                                  Thriller
# 3     Alexandra Shipp                    Drama Adventure Family
# 4       Nicole Kidman                              Comedy Drama
# ..                ...                                       ...
# 247     Rashida Jones  Animation Action Adventure Comedy Family
# 248     Florence Pugh                             Drama Romance
# 249       Mark Strong                         War History Drama
# 250       Brie Larson                       Drama Crime History
# 251       Aldis Hodge                                     Drama
#
#            movie_title                                               comb
# 0          escape room  Adam Robitel (director); Bragi F. Schut Logan ...
# 1           rust creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2     american hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3     a dog's way home  Charles Martin Smith (director); W. Bruce Came...
# 4           the upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                 ...                                                ...
# 247  spies in disguise  Nick Bruno Tom Holland Rashida Jones Nick Brun...
# 248       little women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 249               1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 250         just mercy  Destin Daniel Cretton (director/screenplay) Ja...
# 251           clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
# [252 rows x 7 columns]

# %%
my_df = pd.concat([new_df18, new_df19], ignore_index=True)

# %%
my_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
old_df = pd.read_csv('new_data.csv')

# %%
old_df
# Out:
#               director_name          actor_1_name            actor_2_name  \
# 0             James Cameron           CCH Pounder        Joel David Moore
# 1            Gore Verbinski           Johnny Depp           Orlando Bloom
# 2                Sam Mendes       Christoph Waltz            Rory Kinnear
# 3         Christopher Nolan             Tom Hardy          Christian Bale
# 4               Doug Walker           Doug Walker              Rob Walker
# ...                     ...                   ...                     ...
# 5359            Jim Strouse      Jessica Williams            Chris O'Dowd
# 5360            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 5361       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 5362  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 5363           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 5359       Keith Stanfield                   Romance Comedy
# 5360     Jean Louisa Kelly                          Romance
# 5361        Tiitus Rantala                   Romance Comedy
# 5362           Gina Holden       Crime Comedy Action Family
# 5363        Akshaye Khanna             Crime Drama Thriller
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5359                       the incredible jessica james
# 5360                                  can't buy my love
# 5361                   thick lashes of lauri mäntyvaara
# 5362                        cop and a half: new recruit
# 5363                                                mom
#
#                                                    comb
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5359  Jessica Williams Chris O'Dowd Keith Stanfield ...
# 5360  Adelaide Kane Benjamin Hollingsworth Jean Loui...
# 5361  Inka Haapamäki Rosa Honkonen Tiitus Rantala Ha...
# 5362  Lou Diamond Phillips Wallace Shawn Gina Holden...
# 5363  Sridevi Kapoor Sajal Ali Akshaye Khanna Ravi U...
#
# [5364 rows x 7 columns]

# %%
final_df = old_df.append(my_df,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7404\2046453413.py in ?()
# ----> 1 final_df = old_df.append(my_df,ignore_index=True)
#
# c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
final_df = pd.concat([old_df, my_df], ignore_index=True)

# %%
final_df
# Out:
#                director_name  \
# 0              James Cameron
# 1             Gore Verbinski
# 2                 Sam Mendes
# 3          Christopher Nolan
# 4                Doug Walker
# ...                      ...
# 5862  Nick Bruno, Troy Quane
# 5863            Greta Gerwig
# 5864              Sam Mendes
# 5865   Destin Daniel Cretton
# 5866         Chinonye Chukwu
#
#                                            actor_1_name          actor_2_name  \
# 0                                           CCH Pounder      Joel David Moore
# 1                                           Johnny Depp         Orlando Bloom
# 2                                       Christoph Waltz          Rory Kinnear
# 3                                             Tom Hardy        Christian Bale
# 4                                           Doug Walker            Rob Walker
# ...                                                 ...                   ...
# 5862                                         Nick Bruno           Tom Holland
# 5863  Greta Gerwig (director/screenplay); Saoirse Ronan           Emma Watson
# 5864  Sam Mendes (director/screenplay); Krysty Wilso...  Dean-Charles Chapman
# 5865        Destin Daniel Cretton (director/screenplay)            Jamie Foxx
# 5866  Chinonye Chukwu (director/screenplay); Alfre W...        Wendell Pierce
#
#               actor_3_name                                    genres  \
# 0                Wes Studi           Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport                  Action Adventure Fantasy
# 2         Stephanie Sigman                 Action Adventure Thriller
# 3     Joseph Gordon-Levitt                           Action Thriller
# 4                  unknown                               Documentary
# ...                    ...                                       ...
# 5862         Rashida Jones  Animation Action Adventure Comedy Family
# 5863         Florence Pugh                             Drama Romance
# 5864           Mark Strong                         War History Drama
# 5865           Brie Larson                       Drama Crime History
# 5866           Aldis Hodge                                     Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5862                                  spies in disguise
# 5863                                       little women
# 5864                                               1917
# 5865                                         just mercy
# 5866                                           clemency
#
#                                                    comb
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5862  Nick Bruno Tom Holland Rashida Jones Nick Brun...
# 5863  Greta Gerwig (director/screenplay); Saoirse Ro...
# 5864  Sam Mendes (director/screenplay); Krysty Wilso...
# 5865  Destin Daniel Cretton (director/screenplay) Ja...
# 5866  Chinonye Chukwu (director/screenplay); Alfre W...
#
# [5867 rows x 7 columns]

# %%
final_df.isna().sum()
# Out:
# director_name       0
# actor_1_name        0
# actor_2_name        0
# actor_3_name        0
# genres              0
# movie_title         0
# comb             4906
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df.to_csv('final_data.csv',index=False)
